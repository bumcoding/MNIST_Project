# %%
# 필요한 모듈 import
# keras : 딥러닝 모델을 구현하는 라이브러리, 이를 통해 CNN을 구현함
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

# 데이터 로드 및 전처리
# MNIST 데이터 크기랑 같이 불러온 이미지의 크기를 조정함
img_rows, img_cols = 28, 28
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 입력한 이미지 형태에 따라
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# convert class vectors to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Image data augmentation
datagen = ImageDataGenerator(
        rotation_range=10,  
        zoom_range = 0.1, 
        width_shift_range=0.1,
        height_shift_range=0.1)

datagen.fit(x_train)

# Define the model
model = Sequential()
model.add(Conv2D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=5, strides=2, padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(64, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=5, strides=2, padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(num_classes, activation='softmax'))

# Compile and fit the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(datagen.flow(x_train,y_train, batch_size=64),
                              epochs = 50, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // 64)

# Save the model
model.save('mnist_model.h5')
# Out:
# Epoch 1/50
# 2023-06-01 14:15:11.411960: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 937/937 [==============================] - 42s 45ms/step - loss: 0.3609 - accuracy: 0.8896 - val_loss: 0.0482 - val_accuracy: 0.9847
# Epoch 2/50
# 937/937 [==============================] - 43s 46ms/step - loss: 0.1081 - accuracy: 0.9672 - val_loss: 0.0292 - val_accuracy: 0.9905
# Epoch 3/50
# 937/937 [==============================] - 44s 47ms/step - loss: 0.0842 - accuracy: 0.9740 - val_loss: 0.0213 - val_accuracy: 0.9926
# Epoch 4/50
# 937/937 [==============================] - 45s 48ms/step - loss: 0.0698 - accuracy: 0.9794 - val_loss: 0.0235 - val_accuracy: 0.9918
# Epoch 5/50
# 937/937 [==============================] - 45s 48ms/step - loss: 0.0634 - accuracy: 0.9817 - val_loss: 0.0248 - val_accuracy: 0.9925
# Epoch 6/50
# 937/937 [==============================] - 45s 48ms/step - loss: 0.0589 - accuracy: 0.9820 - val_loss: 0.0215 - val_accuracy: 0.9928
# Epoch 7/50
# 937/937 [==============================] - 46s 49ms/step - loss: 0.0523 - accuracy: 0.9845 - val_loss: 0.0260 - val_accuracy: 0.9915
# Epoch 8/50
# 937/937 [==============================] - 52s 56ms/step - loss: 0.0497 - accuracy: 0.9851 - val_loss: 0.0176 - val_accuracy: 0.9937
# Epoch 9/50
# 937/937 [==============================] - 53s 57ms/step - loss: 0.0461 - accuracy: 0.9865 - val_loss: 0.0181 - val_accuracy: 0.9940
# Epoch 10/50
# 937/937 [==============================] - 54s 57ms/step - loss: 0.0448 - accuracy: 0.9871 - val_loss: 0.0152 - val_accuracy: 0.9943
# Epoch 11/50
# 937/937 [==============================] - 53s 57ms/step - loss: 0.0415 - accuracy: 0.9877 - val_loss: 0.0197 - val_accuracy: 0.9936
# Epoch 12/50
# 937/937 [==============================] - 52s 56ms/step - loss: 0.0399 - accuracy: 0.9884 - val_loss: 0.0174 - val_accuracy: 0.9950
# Epoch 13/50
# 937/937 [==============================] - 53s 56ms/step - loss: 0.0378 - accuracy: 0.9892 - val_loss: 0.0157 - val_accuracy: 0.9949
# Epoch 14/50
# 937/937 [==============================] - 55s 59ms/step - loss: 0.0373 - accuracy: 0.9889 - val_loss: 0.0187 - val_accuracy: 0.9947
# Epoch 15/50
# 937/937 [==============================] - 56s 59ms/step - loss: 0.0328 - accuracy: 0.9902 - val_loss: 0.0167 - val_accuracy: 0.9950
# Epoch 16/50
# 937/937 [==============================] - 54s 58ms/step - loss: 0.0347 - accuracy: 0.9897 - val_loss: 0.0144 - val_accuracy: 0.9952
# Epoch 17/50
# 937/937 [==============================] - 53s 57ms/step - loss: 0.0324 - accuracy: 0.9905 - val_loss: 0.0149 - val_accuracy: 0.9954
# Epoch 18/50
# 937/937 [==============================] - 53s 57ms/step - loss: 0.0311 - accuracy: 0.9911 - val_loss: 0.0164 - val_accuracy: 0.9952
# Epoch 19/50
# 937/937 [==============================] - 51s 55ms/step - loss: 0.0288 - accuracy: 0.9919 - val_loss: 0.0160 - val_accuracy: 0.9953
# Epoch 20/50
# 937/937 [==============================] - 58s 62ms/step - loss: 0.0298 - accuracy: 0.9905 - val_loss: 0.0183 - val_accuracy: 0.9944
# Epoch 21/50
# 937/937 [==============================] - 55s 59ms/step - loss: 0.0285 - accuracy: 0.9913 - val_loss: 0.0196 - val_accuracy: 0.9948
# Epoch 22/50
# 937/937 [==============================] - 52s 56ms/step - loss: 0.0261 - accuracy: 0.9924 - val_loss: 0.0159 - val_accuracy: 0.9952
# Epoch 23/50
# 937/937 [==============================] - 52s 55ms/step - loss: 0.0283 - accuracy: 0.9918 - val_loss: 0.0317 - val_accuracy: 0.9922
# Epoch 24/50
# 937/937 [==============================] - 52s 56ms/step - loss: 0.0271 - accuracy: 0.9916 - val_loss: 0.0172 - val_accuracy: 0.9951
# Epoch 25/50
# 937/937 [==============================] - 52s 56ms/step - loss: 0.0250 - accuracy: 0.9927 - val_loss: 0.0172 - val_accuracy: 0.9941
# Epoch 26/50
# 937/937 [==============================] - 53s 56ms/step - loss: 0.0251 - accuracy: 0.9923 - val_loss: 0.0142 - val_accuracy: 0.9964
# Epoch 27/50
# 937/937 [==============================] - 53s 57ms/step - loss: 0.0235 - accuracy: 0.9932 - val_loss: 0.0172 - val_accuracy: 0.9953
# Epoch 28/50
# 937/937 [==============================] - 53s 57ms/step - loss: 0.0238 - accuracy: 0.9931 - val_loss: 0.0123 - val_accuracy: 0.9966
# Epoch 29/50
# 937/937 [==============================] - 122s 130ms/step - loss: 0.0227 - accuracy: 0.9930 - val_loss: 0.0126 - val_accuracy: 0.9958
# Epoch 30/50
# 937/937 [==============================] - 45s 48ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 0.0153 - val_accuracy: 0.9952
# Epoch 31/50
# 937/937 [==============================] - 43s 46ms/step - loss: 0.0218 - accuracy: 0.9933 - val_loss: 0.0127 - val_accuracy: 0.9961
# Epoch 32/50
# 937/937 [==============================] - 46s 50ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 0.0122 - val_accuracy: 0.9965
# Epoch 33/50
# 937/937 [==============================] - 58s 62ms/step - loss: 0.0208 - accuracy: 0.9935 - val_loss: 0.0159 - val_accuracy: 0.9953
# Epoch 34/50
# 937/937 [==============================] - 56s 60ms/step - loss: 0.0211 - accuracy: 0.9937 - val_loss: 0.0147 - val_accuracy: 0.9951
# Epoch 35/50
# 937/937 [==============================] - 52s 56ms/step - loss: 0.0210 - accuracy: 0.9937 - val_loss: 0.0151 - val_accuracy: 0.9953
# Epoch 36/50
# 937/937 [==============================] - 51s 55ms/step - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.0160 - val_accuracy: 0.9945
# Epoch 37/50
# 937/937 [==============================] - 49s 53ms/step - loss: 0.0219 - accuracy: 0.9934 - val_loss: 0.0154 - val_accuracy: 0.9953
# Epoch 38/50
# 937/937 [==============================] - 48s 51ms/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.0124 - val_accuracy: 0.9961
# Epoch 39/50
# 937/937 [==============================] - 51s 55ms/step - loss: 0.0198 - accuracy: 0.9943 - val_loss: 0.0124 - val_accuracy: 0.9959
# Epoch 40/50
# 937/937 [==============================] - 53s 57ms/step - loss: 0.0197 - accuracy: 0.9941 - val_loss: 0.0153 - val_accuracy: 0.9956
# Epoch 41/50
# 937/937 [==============================] - 57s 61ms/step - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.0138 - val_accuracy: 0.9959
# Epoch 42/50
# 937/937 [==============================] - 58s 62ms/step - loss: 0.0190 - accuracy: 0.9943 - val_loss: 0.0147 - val_accuracy: 0.9956
# Epoch 43/50
# 937/937 [==============================] - 56s 60ms/step - loss: 0.0183 - accuracy: 0.9946 - val_loss: 0.0134 - val_accuracy: 0.9965
# Epoch 44/50
# 937/937 [==============================] - 53s 56ms/step - loss: 0.0192 - accuracy: 0.9944 - val_loss: 0.0153 - val_accuracy: 0.9956
# Epoch 45/50
# 937/937 [==============================] - 53s 56ms/step - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.0118 - val_accuracy: 0.9971
# Epoch 46/50
# 937/937 [==============================] - 51s 54ms/step - loss: 0.0183 - accuracy: 0.9944 - val_loss: 0.0121 - val_accuracy: 0.9964
# Epoch 47/50
# 937/937 [==============================] - 51s 54ms/step - loss: 0.0179 - accuracy: 0.9948 - val_loss: 0.0119 - val_accuracy: 0.9960
# Epoch 48/50
# 937/937 [==============================] - 49s 52ms/step - loss: 0.0169 - accuracy: 0.9952 - val_loss: 0.0140 - val_accuracy: 0.9958
# Epoch 49/50
# 937/937 [==============================] - 49s 53ms/step - loss: 0.0189 - accuracy: 0.9941 - val_loss: 0.0128 - val_accuracy: 0.9958
# Epoch 50/50
# 937/937 [==============================] - 52s 56ms/step - loss: 0.0174 - accuracy: 0.9947 - val_loss: 0.0129 - val_accuracy: 0.9958

# %%
import cv2
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# Load the model
model = load_model('mnist_model.h5')

# Load the image file
img = cv2.imread('0_Bad.png', cv2.IMREAD_GRAYSCALE)

# Display the image
plt.imshow(img, cmap='gray')
plt.show()

# Resize and reshape the image
img_resized = cv2.resize(img, (28, 28))
img_ready = img_resized.reshape(1, 28, 28, 1)

# Normalize the image
img_ready = img_ready.astype('float32')
img_ready /= 255

# Predict the digit
proba = model.predict(img_ready)
digit = np.argmax(proba)

# Print the predicted digit
print("삐-빅, 이 숫자는", digit,"입니다. 휴-먼")

# Print each class's probability
for i in range(10):
    print(f"Class {i}: {proba[0][i] * 100:.2f}%")
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 삐-빅, 이 숫자는 0 입니다. 휴-먼
# Class 0: 74.16%
# Class 1: 0.08%
# Class 2: 3.16%
# Class 3: 0.64%
# Class 4: 0.05%
# Class 5: 1.34%
# Class 6: 1.74%
# Class 7: 0.04%
# Class 8: 13.42%
# Class 9: 5.38%
